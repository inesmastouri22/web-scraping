# %% [markdown]
# This is a trial of data scraping from LinkedIn  (I put my LinkedIn URL profile as an example)

# %%
import requests

#you can get your API key from proxcurl
api_key = 'You API Key'
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
params = {
    'linkedin_profile_url': 'https://www.linkedin.com/in/ines-mastouri/',
    'extra': 'include',
    'github_profile_id': 'include',
    'facebook_profile_id': 'include',
    'twitter_profile_id': 'include',
    'personal_contact_number': 'include',
    'personal_email': 'include',
    'inferred_salary': 'include',
    'skills': 'include',
    'use_cache': 'if-present',
    'fallback_to_cache': 'on-error',
}
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

# %%
profile_data = response.json()
profile_data
# Out:
# {'public_identifier': 'ines-mastouri',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/ines-mastouri/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113253Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=00298f261b462a2af4c4e83d3771cd9cd77bbfb6590cd5bed9ef4f4a907abc49',
#  'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/ines-mastouri/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113253Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=e59330e6e0ac755e67c97a126a6b930db4fbb8587bda81744c99af2c7b6e30e0',
#  'first_name': 'Ines',
#  'last_name': 'Mastouri',
#  'full_name': 'Ines Mastouri',
#  'follower_count': 1132,
#  'occupation': 'AI and Data Analyst Marketing at Outzip - Circular Operating System',
#  'headline': 'Intelligent Decision Making Strategies Master of Research Student @ISG TUNIS',
#  'summary': "I am passionate about applying data-driven strategies to real-world challenges, especially in the fields of healthcare, education and sustainability. I am currently pursuing a master's degree of research in Intelligent Decision-Making Strategies at the Higher Institute of Management, University of Tunis, where I enhance my skills and knowledge in data science and AI. I have a bachelor's degree in Business Intelligence from the University of Tunis El Manar. I am interested in learning from industry leaders and fast-track my skills by working on tangible projects.",
#  'country': 'TN',
#  'country_full_name': 'Tunisia',
#  'city': 'Tunis',
#  'state': None,
#  'experiences': [{'starts_at': {'day': 1, 'month': 3, 'year': 2024},
#    'ends_at': {'day': 30, 'month': 6, 'year': 2024},
#    'company': 'Outzip - Circular Operating System',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/outzip',
#    'company_facebook_profile_url': None,
#    'title': 'AI and Data Analyst Marketing',
#    'description': '-Developing a SEO research and strategy plan.\n-Identifying and defining content keywords for SEO purposes.\n-Scraping data to populate the databases.\n-Working on reliable bot.\n-Testing the website.',
#    'location': 'Berlin, Germany',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/outzip/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113256Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=5df51b03dbbda88b7cfdfb78ac908f0aab9944e58f39aec53a1dd6f773a6ece5'},
#   {'starts_at': {'day': 1, 'month': 1, 'year': 2024},
#    'ends_at': {'day': 31, 'month': 3, 'year': 2024},
#    'company': 'SCALEUP.',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/scaleup-vision',
#    'company_facebook_profile_url': None,
#    'title': 'AI and Business Analyst',
#    'description': '- Prioritize an AI-centric approach for comprehensive utilization.\n- Conduct insightful, on-demand analyses for global market research, offering actionable reports on key business trends.\n- Collaborate with teams to generate valuable content using BI and market insights solutions.\n- Develop client-specific dashboards and descriptive analytics solutions.\n- Compile technical reports by analyzing and summarizing information and trends.\n- Manage data integration and oversee database maintenance.\n- Provide ongoing support for existing BI solutions, swiftly resolving any issues.',
#    'location': 'Luxembourg, Luxembourg',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/scaleup-vision/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=ba88a34d832e30e69ca5667b11776c15ff2c623db81585d55ac50df6d9abde2a'},
#   {'starts_at': {'day': 1, 'month': 8, 'year': 2023},
#    'ends_at': {'day': 29, 'month': 2, 'year': 2024},
#    'company': 'Green Cloud Nine',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/green-cloud-nine',
#    'company_facebook_profile_url': None,
#    'title': 'Business Developer and Data Analyst',
#    'description': "- Contributed to the definition of the company’s business development strategy.\n- Was proactive in the identification and tracking of new business opportunities, including suppliers, products and growth areas.\n- Managed the lead's pipeline, trackied communications and built relationships with potential and existing suppliers.\n- Affiliate Program Applications: Regularly applying for affiliate programs via the ADCELL platform.\n- Database Management: Updating and maintaining a database of suppliers.\n- Status Updates: Monitoring and updating the status of supplier applications (Accepted, rejected, program ended).\n- Product Selection: Choosing specific products across various categories like gifts,cosmetics, gardening, etc.\n- Deep link Generation: Creating deep links for selected products to track affiliate\nreferrals.\n- Product Information Completion: Filling in details such as price, tags, and supplier links for each product.\n- Copywriting: Compiling product specifications from supplier websites and\ngenerating descriptive content.",
#    'location': 'Innsbruck, Austria',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/green-cloud-nine/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=48456b4d15271e00801562a09ae635666f0aa5e7e91a693cb4991241e5d1b594'},
#   {'starts_at': {'day': 1, 'month': 3, 'year': 2023},
#    'ends_at': {'day': 31, 'month': 8, 'year': 2023},
#    'company': 'Project C Foundation - We Care For Your Mental Health',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/projectcfoundation',
#    'company_facebook_profile_url': None,
#    'title': 'Web Developer',
#    'description': 'Creating website layout/user interface by using standard web development practices.\nRegular updation of the website according to the changes prescribed.\nResponsibility of maintaining, expanding, and scaling the websit.',
#    'location': 'India',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/projectcfoundation/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=983869768e78d37ab067343b450804d2b873ee5afd308f9b71e57d0cce6c1a68'},
#   {'starts_at': {'day': 1, 'month': 3, 'year': 2023},
#    'ends_at': {'day': 30, 'month': 6, 'year': 2023},
#    'company': 'EcoWillowGh',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/ecowillowgh',
#    'company_facebook_profile_url': None,
#    'title': 'Graphic Designer',
#    'description': 'I dedicated my time as a volunteer graphic designer, where I had the rewarding opportunity to contribute my creativity and design skills to various causes. One of my key responsibilities was creating eye-catching posters that effectively conveyed important messages and promoted events. Additionally, I supported the organization in developing designs for, specialized posters, and designs for an upcoming long-term event. This role allowed me to blend my passion for design with my desire to make a positive impact in my community. It was a fulfilling experience that showcased the power of visual communication in inspiring change and engagement.',
#    'location': 'Ghana',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/ecowillowgh/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=8035813049f672b046e498474a25d98f92a8e93597667e600ae662b55722164f'},
#   {'starts_at': {'day': 1, 'month': 2, 'year': 2023},
#    'ends_at': {'day': 31, 'month': 5, 'year': 2023},
#    'company': 'VERMEG for Banking & Insurance Software',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/vermeg',
#    'company_facebook_profile_url': None,
#    'title': 'End of Studies Internship ',
#    'description': None,
#    'location': 'Tunis, Tunisia',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/vermeg/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=00e10655b3cbd70a7ca982d105c94eff59d3199ee961515ea559c85e919d6b66'},
#   {'starts_at': {'day': 1, 'month': 12, 'year': 2022},
#    'ends_at': {'day': 28, 'month': 2, 'year': 2023},
#    'company': 'Project C Foundation - We Care For Your Mental Health',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/projectcfoundation',
#    'company_facebook_profile_url': None,
#    'title': 'Content and Research Development',
#    'description': 'Consistently brainstorm and collaborate with the team for new ideas and strategies. \nBuild brand awareness through content on social media channels. \nResearch markets and industries to compare and create innovative and original content. \nCollaborate with campaign managers, creative team, and designers. \nWrite on a wide variety of topics for multiple platforms (website, blogs, articles, social updates, banners, case studies, guides, white papers, etc.).',
#    'location': 'Remote',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/projectcfoundation/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=983869768e78d37ab067343b450804d2b873ee5afd308f9b71e57d0cce6c1a68'},
#   {'starts_at': {'day': 1, 'month': 8, 'year': 2022},
#    'ends_at': {'day': 30, 'month': 9, 'year': 2022},
#    'company': 'ANSI - tunCERT ',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/ancs-tuncert',
#    'company_facebook_profile_url': None,
#    'title': 'Network Security',
#    'description': 'During my one-month internship, I had the valuable opportunity to immerse myself in the world of network security. Working with pfSense, I gained hands-on experience in configuring and managing network firewall solutions. This experience not only deepened my understanding of network security principles but also enhanced my skills in safeguarding network infrastructure. It was an intensive and insightful month that allowed me to apply theoretical knowledge in a practical setting, strengthening my foundation in the field of network security.',
#    'location': 'Tunis, Tunisia',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/ancs-tuncert/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=38f1b6b6e426a395dd957efcca75e34e0548278dd28376c48fba8b03ae2845ad'},
#   {'starts_at': {'day': 1, 'month': 7, 'year': 2022},
#    'ends_at': {'day': 31, 'month': 7, 'year': 2022},
#    'company': 'TMI Tunisia',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/tmi-tunisia',
#    'company_facebook_profile_url': None,
#    'title': 'Virtualization',
#    'description': 'During my one-month internship at TMI, I had the privilege of delving into the realm of virtualization. This experience provided me with hands-on exposure to virtualization technologies, where I had the opportunity to work with various virtualization platforms and solutions. Over the course of the internship, I honed my skills in setting up, configuring, and managing virtualized environments. This practical experience not only expanded my knowledge of virtualization but also reinforced my ability to optimize resources and streamline operations through virtualization technologies.',
#    'location': 'al-Karam, Tunis, Tunisia',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/tmi-tunisia/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113255Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=0738cb32f00d1b59cd084847615276320c5db49bbf66a52d17f63627d2f4f6aa'}],
#  'education': [{'starts_at': {'day': 1, 'month': 9, 'year': 2023},
#    'ends_at': {'day': 30, 'month': 6, 'year': 2025},
#    'field_of_study': 'Intelligent Decision Making Strategy',
#    'degree_name': 'Research Master Degree',
#    'school': 'Institut Supérieur de Gestion de Tunis',
#    'school_linkedin_profile_url': 'https://www.linkedin.com/company/11163068/',
#    'school_facebook_profile_url': None,
#    'description': "I am pursuing a research master's degree of Intelligent Decision-Making Strategy at the Higher Institute of Management. This degree offers a comprehensive exploration of cutting-edge fields such as data science, artificial intelligence (AI), and project management. Through rigorous academic coursework and hands-on research projects, I am gaining in-depth insights into the strategic application of data-driven approaches, AI technologies, and effective project management methodologies. I am passionate about leveraging these skills to make informed, data-backed decisions and drive innovation.",
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/institutsup%C3%A9rieurdegestiondetunis/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113256Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=61dae8130af684ec5b82e2fbc76c3ebbc23be9ab542f99a37a144efc3c538cde',
#    'grade': None,
#    'activities_and_societies': None},
#   {'starts_at': {'day': 1, 'month': 9, 'year': 2020},
#    'ends_at': {'day': 31, 'month': 5, 'year': 2023},
#    'field_of_study': 'Business Intelligence',
#    'degree_name': "Bachelor's degree",
#    'school': 'University of Tunis El Manar',
#    'school_linkedin_profile_url': 'https://www.linkedin.com/company/15099379/',
#    'school_facebook_profile_url': None,
#    'description': "I graduated with a bachelor of Business Intelligence from the University of Tunis El Manar. My education provided me with a foundation in data analysis, data warehousing, and business intelligence tools. Beyond academics, I actively participated in extracurricular activities that enhanced my teamwork and leadership skills. Proficient in data visualization, SQL, data mining, and BI tools like Tableau and Power BI, I'm eager to contribute my skills and passion for data-driven decision-making to drive business success.",
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/university-of-tunis-el-manar/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113256Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=c18503f1efb3deeec22884fa24f6da3e33a64a8e76c6d9b887942711813639a9',
#    'grade': None,
#    'activities_and_societies': 'I actively participated in extracurricular activities. I served as the Academic Affairs Department Manager at TIMUN ISG (Tunis International Model United Nations) and was a member of JCI FSEGT, contributing to community development. I was part of the National Club within the National Association of University Clubs, engaging in various educational and social initiatives. These experiences enriched my learning and reinforced my commitment to personal growth and community involvement'},
#   {'starts_at': {'day': 1, 'month': 8, 'year': 2022},
#    'ends_at': {'day': 30, 'month': 9, 'year': 2022},
#    'field_of_study': None,
#    'degree_name': 'Summer university',
#    'school': 'Johannes Kepler Universität Linz',
#    'school_linkedin_profile_url': 'https://www.linkedin.com/company/49299/',
#    'school_facebook_profile_url': None,
#    'description': 'I have participated in a transformative four-week experience at Ars Electronica and JKU Festival University 2022 in Linz, collaborating with 200 students from 70 countries alongside eminent scientists, artists, and experts from diverse fields of art, technology, science, and society.\n\nExplored the quest for an international constitution for climate protection, culminating in a compelling simulation of the International Environmental and Climate Court (IECC). Presented ideas and insights gained from this collective effort during the realistic court simulation held on September 9th, 10th, and 11th.\n\nGrateful for the opportunity to contribute to such a groundbreaking initiative bridging disciplines for global climate action!',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/jkulinz/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240823%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240823T113256Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=a8f1cf9e3a4b832ebf9614808c09c12ab2aa38b05a2a5fc857390715d570b6f0',
#    'grade': None,
#    'activities_and_societies': None},
#   {'starts_at': {'day': 1, 'month': 9, 'year': 2019},
#    'ends_at': {'day': 31, 'month': 7, 'year': 2020},
#    'field_of_study': 'Computer Science',
#    'degree_name': 'Baccalaureat ',
#    'school': 'High School Mourouj 6',
#    'school_linkedin_profile_url': None,
#    'school_facebook_profile_url': None,
#    'description': 'Skills: SQL · Volunteering · Active Listening · Cascading Style Sheets (CSS) · Interpersonal Skills',
#    'logo_url': None,
#    'grade': None,
#    'activities_and_societies': None},
#   {'starts_at': {'day': 1, 'month': 9, 'year': 2016},
#    'ends_at': {'day': 31, 'month': 5, 'year': 2019},
#    'field_of_study': None,
#    'degree_name': 'Computer Science',
#    'school': 'High School Mourouj 1',
#    'school_linkedin_profile_url': None,
#    'school_facebook_profile_url': None,
#    'description': None,
#    'logo_url': None,
#    'grade': None,
#    'activities_and_societies': None}],
#  'languages': ['Arabic', 'English', 'French', 'Germany ', 'Turkish'],
#  'accomplishment_organisations': [],
#  'accomplishment_publications': [],
#  'accomplishment_honors_awards': [],
#  'accomplishment_patents': [],
#  'accomplishment_courses': [],
#  'accomplishment_projects': [{'starts_at': {'day': 1,
#     'month': 4,
#     'year': 2024},
#    'ends_at': {'day': 30, 'month': 4, 'year': 2024},
#    'title': 'Survey presentation: A survey of Big Data dimensions vs Social Networks analysis',
#    'description': 'Presentation link: https://urlz.fr/qlDr',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 3, 'year': 2024},
#    'ends_at': {'day': 31, 'month': 3, 'year': 2024},
#    'title': 'Article presentation: Coronavirus disease (COVID‑19) cases analysis using machine‑learning  applications',
#    'description': 'This presentation, titled " Analysis of Coronavirus Disease (COVID-19) Cases Using Machine-Learning Applications" was conducted as part of the Experimental Design Methods course.',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 12, 'year': 2023},
#    'ends_at': {'day': 31, 'month': 12, 'year': 2023},
#    'title': 'Data science course project',
#    'description': None,
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 9, 'year': 2023},
#    'ends_at': {'day': 30, 'month': 9, 'year': 2023},
#    'title': 'Prime video - Analytic dashboard - Power BI',
#    'description': None,
#    'url': None}],
#  'accomplishment_test_scores': [],
#  'volunteer_work': [{'starts_at': {'day': 1, 'month': 7, 'year': 2023},
#    'ends_at': {'day': 31, 'month': 8, 'year': 2023},
#    'title': 'Volunteer at the Youth House of Timişoara, Romania',
#    'cause': 'Social Services',
#    'company': 'European Solidarity Corps for Youth (ESC4Y)',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/12615553/',
#    'description': "I have managed and planned several events, workshops, and activities, covering pre-established topics. My involvement spans from the initial planning stages to the meticulous execution and evaluation of each event, ensuring a seamless and impactful experience. \n\nNotably, I have led these initiatives alongside a multicultural team, fostering diverse perspectives and ideas throughout the entire process. Specifically dedicated to the youth of Timisoara and more broadly in Romania, our events, such as talent shows, living library, and meticulous preparations for the Youth Summer Festival, have resonated with the vibrant energy of the younger generation. Beyond the execution, I diligently evaluate each event's success, capturing its impact and subsequently writing comprehensive reports. \n\nThis approach extends to providing essential information about the activities for magazine features and other promotional channels, showcasing our interest in engaging and culturally enriching experiences for our audiences.",
#    'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQEDjhrU6nLH5g/company-logo_400_400/company-logo_400_400/0/1630487833944/european_solidarity_corps_for_youth_logo?e=1732752000&v=beta&t=K9cEG0mygbPDylVG9MxSBzDRob85Moq_nwv8OTmNxZM'},
#   {'starts_at': {'day': 1, 'month': 7, 'year': 2022},
#    'ends_at': {'day': 30, 'month': 9, 'year': 2022},
#    'title': 'Workshop Organiser ',
#    'cause': 'Social Services',
#    'company': 'Yellow vs. Blue | Mental Health',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/71548375/',
#    'description': 'Working with a global organization that seeks to assist people and care for their well-being was educational for me, and volunteering is always an enjoyable experience.',
#    'logo_url': 'https://media.licdn.com/dms/image/v2/C4D0BAQE8Lh8uCQhCYQ/company-logo_400_400/company-logo_400_400/0/1630460985801?e=1732752000&v=beta&t=Fslxfix6GLEomDMunV1oUOS_9FxhQCegtFoa29gbKfI'},
#   {'starts_at': {'day': 1, 'month': 9, 'year': 2021},
#    'ends_at': {'day': 30, 'month': 6, 'year': 2022},
#    'title': 'Academic Affairs Department Manager (TIMUN ISG)',
#    'cause': 'Civil Rights',
#    'company': 'Tunisian International Model United Nations (TIMUN)',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/11093096/',
#    'description': None,
#    'logo_url': 'https://media.licdn.com/dms/image/v2/C4E0BAQGFqhXhDbIlxw/company-logo_400_400/company-logo_400_400/0/1631893991178/timun_logo?e=1732752000&v=beta&t=0l8K4jThdKguAk67tdS6rJryemQ2rD01YZdYXhw8Dfo'}],
#  'certifications': [{'starts_at': {'day': 1, 'month': 12, 'year': 2022},
#    'ends_at': None,
#    'name': 'Connect Global Student Certificate',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'Soliya',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 6, 'year': 2019},
#    'ends_at': None,
#    'name': 'DELF B2',
#    'license_number': '216012-201904J-4400370',
#    'display_source': None,
#    'authority': 'Institut français de Tunisie',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 8, 'year': 2018},
#    'ends_at': None,
#    'name': 'Sprachzertifikat Deutch',
#    'license_number': 'CRT4660171213',
#    'display_source': None,
#    'authority': 'Educaro Tunisia',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 2, 'year': 2023},
#    'ends_at': None,
#    'name': 'Global Circle - February 2023',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'Soliya',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 3, 'year': 2023},
#    'ends_at': None,
#    'name': 'Google Africa Developer Training Program',
#    'license_number': '20ECF2BE82D0FC5',
#    'display_source': 'adscerts.com',
#    'authority': 'Google',
#    'url': 'https://adscerts.com/scholar/20ECF2BE82D0FC5'},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2023},
#    'ends_at': None,
#    'name': 'EF SET - C1 Level',
#    'license_number': '7r4XJc',
#    'display_source': 'efset.org',
#    'authority': 'EF Standard English Test (EF SET) ',
#    'url': 'https://www.efset.org/cert/7r4XJc'},
#   {'starts_at': {'day': 1, 'month': 4, 'year': 2023},
#    'ends_at': None,
#    'name': 'Global Circle - April 2023',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'Soliya',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2023},
#    'ends_at': None,
#    'name': 'Global Circle - October 2023',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'Soliya',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2023},
#    'ends_at': None,
#    'name': 'Business Analysis by practice ',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'IIBA',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 8, 'year': 2023},
#    'ends_at': None,
#    'name': 'LOCALINTERNational 2023',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'Türkiye Belediyeler Birliği / Union of Municipalities of Türkiye | Official Page',
#    'url': None}],
#  'connections': 1017,
#  'people_also_viewed': [{'link': 'https://www.linkedin.com/in/rezgani-cyrine?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAC5iFHEBuj8I0ijQi7M3UKHtRmYJnPDo1us',
#    'name': 'Cyrine Rezgani',
#    'summary': 'Sales Executives at Modern Solution Co.Ltd',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/wajdi-zeidi?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABc-CWgBDgUB5Pr4ry_wFTk-sA3NIi2TE1o',
#    'name': 'Wajdi ZEIDI 🌐',
#    'summary': '+38K🚀 | Marketing & Communications Specialist 📈 | Digital Marketing Instructor 💼 | Captain of Creative Chaos 👨\u200d💼 |  University Speaker & Facilitator 🎤🎯',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/farah-bali?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADaKHyIBJB2GTcO4Jfz-ueJkBKHexL85vhU',
#    'name': 'Farah Bali',
#    'summary': 'Web Developer | Javascript | Typescript | React | Redux | Node js | QA testing',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/ahmed-feki-99a529174?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACleYEYB9Cs7kEA6EVoTXIlP6dufkYfdhf4',
#    'name': 'Ahmed Feki',
#    'summary': "NOVA SBE Master's Student",
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/amira-dridi-527514109?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAABtOeu8BdZbcg19xK9QzMMJ0AMrEmDE3cFM',
#    'name': 'Amira Dridi',
#    'summary': 'Associate Professor in Quantitative Methods chez Tunis Business School',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/malek-mouadhen-%F0%9F%9F%AA-3224a8232?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADoX8coBtxii3AlNrzW0ZMVxUO3J2ckkYu8',
#    'name': 'Malek Mouadhen 🟪',
#    'summary': 'IT Recruiter ✨ We are HIRING 🚀 | Nearshore Software Development Solutions | malek@solvers.fr',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/chiheb-chaabane-620853156?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAACWALLgBRiC4QM9D66r7eDRsyvslCrrNNeY',
#    'name': 'Chiheb Chaabane',
#    'summary': 'ERP Functional Consultant | Financial Systems Specialist || Master In Business Management Graduate: Finance Specialization 📍SMU',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/rania-barka-4118b5224?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADhfvw0BjnnVK3_C5NWVPf0L9Nf2_Y7AvoU',
#    'name': 'Rania Barka',
#    'summary': 'Student at SMU - South Mediterranean University (MSB- MedTech-LCI)',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/nicolealkassas?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAADZ15GoBLFcIUvKHyjHG_9avO_Zj7CbA8qg',
#    'name': 'Nicole Alkassas',
#    'summary': 'Web Developer',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/habib-said777?miniProfileUrn=urn%3Ali%3Afs_miniProfile%3AACoAAENULrgBuKG162T5HR1RXrAZqgenvVyRxfc',
#    'name': 'Habib SAID',
#    'summary': '"Game Developer | Transforming Ideas into Digital Innovation 💻🎨 | Eager to Learn and Connect in the Tech World"',
#    'location': None}],
#  'recommendations': [],
#  'activities': [],
#  'similarly_named_profiles': [],
#  'articles': [],
#  'groups': [{'profile_pic_url': 'https://media.licdn.com/dms/image/v2/C4E07AQGeORUsa-kiiA/group-logo_image-shrink_48x48/group-logo_image-shrink_48x48/0/1631004879131?e=1725019200&v=beta&t=dK4x10_ghjQZBpasrJqLRRHJJicGNu5RGd8_OU6C3s4',
#    'name': 'AI / ML,Gen AI & DATA Analytics, Data Science . SAP BI/ Analytics Cloud /Tableau /Power BI /Birst   ',
#    'url': 'https://www.linkedin.com/groups/1859449'},
#   {'profile_pic_url': 'https://media.licdn.com/dms/image/v2/C5607AQGEJj1e6u3rzA/group-logo_image-shrink_48x48/group-logo_image-shrink_48x48/0/1631428575820?e=1725019200&v=beta&t=D5zxYpvpCUiLmz-ya3x6M4YkZF3LWBiNUE36nJxatf0',
#    'name': 'PowerBI',
#    'url': 'https://www.linkedin.com/groups/6718028'}],
#  'skills': ['Research',
#   'Large Language Models (LLM)',
#   'Social Network Analysis',
#   'Big Data',
#   'Critical Thinking',
#   'Exploring',
#   'Debate',
#   'Culture Change',
#   'Cross-Cultural Communication Skills',
#   'Canva',
#   'Research Skills',
#   'Artificial Intelligence (AI)',
#   'Machine Learning',
#   'Predictive Modeling',
#   'Search Engine Optimization (SEO)',
#   'Python (Programming Language)',
#   'Project Management',
#   'Scrum',
#   'Strategic Planning',
#   'Business Development',
#   'SQL',
#   'Graphic Design',
#   'Team Work',
#   'Leadership',
#   'communication',
#   'critical thinking ',
#   'active listening ',
#   'Extract, Transform, Load (ETL)',
#   'Microsoft Power BI',
#   'Data Analysis',
#   'Node.js',
#   'PhpMyAdmin',
#   'Web Development',
#   'User Interface Design',
#   'User Experience (UX)',
#   'Flutter',
#   'Mobile Application Development',
#   'Figma',
#   'Report Writing',
#   'Presentation Skills',
#   'Public Speaking',
#   'Online Research',
#   'Blogging',
#   'Time Management',
#   'Networking',
#   'clubs',
#   'Volunteering',
#   'pfSense',
#   'Network Security',
#   'Network Architecture',
#   'Virtualization',
#   'VMware',
#   'Creativity Skills',
#   'Interpersonal Skills',
#   'Teamwork',
#   'Problem Solving',
#   'Management',
#   'Analytical Skills',
#   'English',
#   'Communication',
#   'PHP',
#   'HTML',
#   'Cascading Style Sheets (CSS)',
#   'JavaScript',
#   'Java',
#   'Active Listening',
#   'oracle',
#   'MySQLi',
#   'MySQL'],
#  'inferred_salary': {'min': None, 'max': None},
#  'gender': None,
#  'birth_date': None,
#  'industry': None,
#  'extra': {'github_profile_id': None,
#   'twitter_profile_id': None,
#   'facebook_profile_id': None},
#  'interests': [],
#  'personal_emails': [],
#  'personal_numbers': []}
