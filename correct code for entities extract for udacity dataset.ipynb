# %%
import requests
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import logging
from rake_nltk import Rake
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache
import numpy as np

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Download NLTK resources
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')

# Load the CSV file
file_path = 'C:/Users/DELL/Downloads/Trainig Dataset1 - Udacity.csv'
df = pd.read_csv(file_path)

# Function to query Wikidata with retry logic, focusing on academic disciplines
@lru_cache(maxsize=10000)
def query_wikidata_academic_discipline(entity):
    url = "https://www.wikidata.org/w/api.php"
    params = {
        'action': 'wbsearchentities',
        'language': 'en',
        'format': 'json',
        'search': entity
    }
    
    session = requests.Session()
    retry = Retry(total=5, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    
    try:
        response = session.get(url, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()
        results = data.get('search', [])
        
        # Assuming the confidence rate is proportional to the ranking of the result
        top_results = results[:int(0.9 * len(results))]  # Consider top 90% of the results
        
        for result in top_results:
            entity_id = result['id']
            entity_url = f"https://www.wikidata.org/wiki/Special:EntityData/{entity_id}.json"
            entity_response = session.get(entity_url)
            entity_response.raise_for_status()
            entity_data = entity_response.json()
            entities = entity_data['entities']
            if entity_id in entities:
                entity_info = entities[entity_id]
                claims = entity_info.get('claims', {})
                
                # Check if the entity is an academic discipline
                if 'P31' in claims:
                    for claim in claims['P31']:
                        if 'mainsnak' in claim and claim['mainsnak']['datavalue']['value']['id'] == 'Q11862829':  # Q11862829 is the Wikidata item for academic discipline
                            return result['label']
        return None
    except requests.exceptions.RequestException as e:
        logging.error(f"Request failed: {e}")
        return None

# Function to extract academic disciplines and keyphrases from text
def extract_academic_disciplines_and_keyphrases(text):
    if pd.isna(text):
        return ""
    
    logging.info(f"Extracting academic disciplines and keyphrases for text: {text[:50]}...")  # Log a snippet of the text being processed
    
    # Tokenize and filter for nouns
    tokens = word_tokenize(text)
    pos_tags = pos_tag(tokens)
    nouns = [word for word, pos in pos_tags if pos.startswith('NN')]
    
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    filtered_nouns = [word for word in nouns if word.lower() not in stop_words]
    
    # Query Wikidata for each noun
    academic_disciplines = []
    for noun in filtered_nouns:
        entity = query_wikidata_academic_discipline(noun)
        if entity:
            academic_disciplines.append(entity)
    
    # Extract keyphrases using RAKE
    rake = Rake(stopwords.words('english'))
    rake.extract_keywords_from_text(text)
    keyphrases = rake.get_ranked_phrases()
    
    # Combine academic disciplines and keyphrases
    combined_entities = set(academic_disciplines + keyphrases)
    
    return ', '.join(combined_entities)

# Process the DataFrame in chunks using ThreadPoolExecutor
def process_chunk(chunk):
    chunk['Extracted Entities'] = chunk['Description'].apply(extract_academic_disciplines_and_keyphrases)
    return chunk

# Split the DataFrame into chunks and process them in parallel
num_chunks = 100  # Increase the number of chunks to better utilize the CPU
chunks = np.array_split(df, num_chunks)

with ThreadPoolExecutor() as executor:
    chunks = list(executor.map(process_chunk, chunks))

# Combine the processed chunks back into a single DataFrame
df = pd.concat(chunks)

# Save the updated DataFrame to a new CSV file
output_file_path = 'C:/Users/DELL/Downloads/dataset.csv'
logging.info(f"Saving the updated DataFrame to {output_file_path}")
df.to_csv(output_file_path, index=False)

# Display the first few rows to verify
logging.info("Displaying the first few rows of the updated DataFrame")
print(df[['Course Name', 'Description', 'Extracted Entities']].head())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\DELL\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# 2024-08-06 10:04:15,871 - INFO - Extracting academic disciplines and keyphrases for text: Digital Project Management enables the creation an...
# 2024-08-06 10:04:15,877 - INFO - Extracting academic disciplines and keyphrases for text: This program will teach you how to become an Azure...
# 2024-08-06 10:04:15,877 - INFO - Extracting academic disciplines and keyphrases for text: Master the computer vision skills behind advances ...
# 2024-08-06 10:04:15,907 - INFO - Extracting academic disciplines and keyphrases for text: The goal of the AWS Machine Learning Engineer (MLE...
# 2024-08-06 10:04:15,951 - INFO - Extracting academic disciplines and keyphrases for text: React is completely transforming the Front-End Dev...
# 2024-08-06 10:04:15,972 - INFO - Extracting academic disciplines and keyphrases for text: The goal of the Security Architect Nanodegree is t...
# 2024-08-06 10:04:15,980 - INFO - Extracting academic disciplines and keyphrases for text: The Introduction to Machine Learning with TensorFl...
# 2024-08-06 10:04:15,996 - INFO - Extracting academic disciplines and keyphrases for text: Master the art of digital freelancing! The program...
# 2024-08-06 10:04:16,015 - INFO - Extracting academic disciplines and keyphrases for text: Learn enterprise scale back-end development with J...
# 2024-08-06 10:04:16,029 - INFO - Extracting academic disciplines and keyphrases for text: Master the skills to get computers to understand, ...
# 2024-08-06 10:04:16,041 - INFO - Extracting academic disciplines and keyphrases for text: Python is a general-purpose coding language with a...
# 2024-08-06 10:04:16,075 - INFO - Extracting academic disciplines and keyphrases for text: Existing PMs wanting to get deeper tech expertise ...
# 2024-08-06 10:04:45,246 - INFO - Extracting academic disciplines and keyphrases for text: Learn to design data models, build data warehouses...
# 2024-08-06 10:05:05,706 - INFO - Extracting academic disciplines and keyphrases for text: This program will focus on the unique knowledge an...
# 2024-08-06 10:05:16,865 - INFO - Extracting academic disciplines and keyphrases for text: In this program, you will learn how to evaluate, m...
# 2024-08-06 10:05:16,999 - INFO - Extracting academic disciplines and keyphrases for text: Master autonomous flight software engineering skil...
# 2024-08-06 10:05:21,431 - INFO - Extracting academic disciplines and keyphrases for text: Gain foundational data skills applicable to market...
# 2024-08-06 10:05:21,471 - INFO - Extracting academic disciplines and keyphrases for text: Gain real-world experience running live campaigns ...
# 2024-08-06 10:05:35,749 - INFO - Extracting academic disciplines and keyphrases for text: Get hands-on experience running data pipelines, de...
# 2024-08-06 10:05:36,327 - INFO - Extracting academic disciplines and keyphrases for text: Learn to clearly define business issues, prepare a...
# 2024-08-06 10:05:37,444 - INFO - Extracting academic disciplines and keyphrases for text: This program will equip students with the skills t...
# 2024-08-06 10:05:44,406 - INFO - Extracting academic disciplines and keyphrases for text: Learn to clean up messy data, uncover patterns and...
# 2024-08-06 10:05:48,224 - INFO - Extracting academic disciplines and keyphrases for text: Youâ€™ll master the foundational skills necessary ...
# 2024-08-06 10:05:50,048 - INFO - Extracting academic disciplines and keyphrases for text: Learn to design data models, build data warehouses...
# 2024-08-06 10:05:50,061 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to create server-side, data-driven web a...
# 2024-08-06 10:05:53,022 - INFO - Extracting academic disciplines and keyphrases for text: This program teaches how to deploy, build, migrate...
# 2024-08-06 10:05:57,272 - INFO - Extracting academic disciplines and keyphrases for text: This Programming for Data Science with R Nanodegre...
# 2024-08-06 10:05:57,922 - INFO - Extracting academic disciplines and keyphrases for text: The Full Stack JavaScript Developer Nanodegree pro...
# 2024-08-06 10:05:58,234 - INFO - Extracting academic disciplines and keyphrases for text: The goal of the Site Reliability Engineer (SRE) Na...
# 2024-08-06 10:05:58,393 - INFO - Extracting academic disciplines and keyphrases for text: The Machine Learning DevOps Engineer Nanodegree pr...
# 2024-08-06 10:05:58,774 - INFO - Extracting academic disciplines and keyphrases for text: The UX Fundamentals & Design Research program teac...
# 2024-08-06 10:05:58,939 - INFO - Extracting academic disciplines and keyphrases for text: Welcome to the world of programming! Learn the ski...
# 2024-08-06 10:06:03,259 - INFO - Extracting academic disciplines and keyphrases for text: Master writing in Swift as you build five portfoli...
# 2024-08-06 10:06:07,303 - INFO - Extracting academic disciplines and keyphrases for text: The AI Product Manager Nanodegree Program offers a...
# 2024-08-06 10:06:12,244 - INFO - Extracting academic disciplines and keyphrases for text: Learn the latest in development technology using A...
# 2024-08-06 10:06:12,454 - INFO - Extracting academic disciplines and keyphrases for text: The Deep Reinforcement Learning Nanodegree has fou...
# 2024-08-06 10:06:15,822 - INFO - Extracting academic disciplines and keyphrases for text: Become an expert in the core concepts of artificia...
# 2024-08-06 10:06:18,920 - INFO - Extracting academic disciplines and keyphrases for text: The AI Engineer using Microsoft Azure Nanodegree p...
# 2024-08-06 10:06:22,384 - INFO - Extracting academic disciplines and keyphrases for text: The Enterprise Security Nanodegree program imparts...
# 2024-08-06 10:06:24,719 - INFO - Extracting academic disciplines and keyphrases for text: Work on the future of autonomous vehicles and help...
# 2024-08-06 10:06:25,882 - INFO - Extracting academic disciplines and keyphrases for text: Become a Front-End Web Developer by completing a v...
# 2024-08-06 10:06:31,621 - INFO - Extracting academic disciplines and keyphrases for text: Master blockchain, from fundamentals to smart cont...
# 2024-08-06 10:06:37,461 - INFO - Extracting academic disciplines and keyphrases for text: Learn SQL.
#
#  Master SQL, the core language for d...
# 2024-08-06 10:06:38,148 - INFO - Extracting academic disciplines and keyphrases for text: In this program, youâ€™ll develop the skills you n...
# 2024-08-06 10:06:42,274 - INFO - Extracting academic disciplines and keyphrases for text: In this program, you will embark on a comprehensiv...
# 2024-08-06 10:06:42,509 - INFO - Extracting academic disciplines and keyphrases for text: This Nanodegree provides an overview of embedded s...
# 2024-08-06 10:06:46,920 - INFO - Extracting academic disciplines and keyphrases for text: Using Azure Machine Learningâ€™s MLOps capabilitie...
# 2024-08-06 10:06:48,035 - INFO - Extracting academic disciplines and keyphrases for text: The AWS Cloud Architect program focuses on designi...
# 2024-08-06 10:06:49,731 - INFO - Extracting academic disciplines and keyphrases for text: This Nanodegree program is intended to elevate you...
# 2024-08-06 10:07:05,050 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we will learn what Robotic Process...
# 2024-08-06 10:07:05,327 - INFO - Extracting academic disciplines and keyphrases for text: The Data Architect Nanodegree program will be to p...
# 2024-08-06 10:07:05,338 - INFO - Extracting academic disciplines and keyphrases for text: Elevate your tech skills with our innovative progr...
# 2024-08-06 10:07:10,432 - INFO - Extracting academic disciplines and keyphrases for text: Learn C++, a high-performance programming language...
# 2024-08-06 10:07:19,701 - INFO - Extracting academic disciplines and keyphrases for text: The Sensor Fusion Engineer Nanodegree program cons...
# 2024-08-06 10:07:23,793 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn some essential and ...
# 2024-08-06 10:07:24,739 - INFO - Extracting academic disciplines and keyphrases for text: Complete real-world projects designed by industry ...
# 2024-08-06 10:07:37,779 - INFO - Extracting academic disciplines and keyphrases for text: Becoming a digital marketer is a journey - let us ...
# 2024-08-06 10:07:39,123 - INFO - Extracting academic disciplines and keyphrases for text: This program will equip any learner who wants to d...
# 2024-08-06 10:07:43,552 - INFO - Extracting academic disciplines and keyphrases for text: Digital Transformation for Business Leaders offers...
# 2024-08-06 10:07:50,608 - INFO - Extracting academic disciplines and keyphrases for text: The Data Science for Business Leaders Executive Pr...
# 2024-08-06 10:07:52,151 - INFO - Extracting academic disciplines and keyphrases for text: SQL is one of the most versatile tools available f...
# 2024-08-06 10:07:55,401 - INFO - Extracting academic disciplines and keyphrases for text: Fuse computer vision, machine learning, mechanics,...
# 2024-08-06 10:07:56,798 - INFO - Extracting academic disciplines and keyphrases for text: In this program, you will dive into the world of D...
# 2024-08-06 10:08:02,668 - INFO - Extracting academic disciplines and keyphrases for text: This Nanodegree trains the learner about foundatio...
# 2024-08-06 10:08:02,678 - INFO - Extracting academic disciplines and keyphrases for text: Learn Python, NumPy, Pandas, Matplotlib, PyTorch, ...
# 2024-08-06 10:08:02,860 - INFO - Extracting academic disciplines and keyphrases for text: The goal of the Security Analyst Nanodegree Progra...
# 2024-08-06 10:08:03,799 - INFO - Extracting academic disciplines and keyphrases for text: Learn basic programming with Python, one of the mo...
# 2024-08-06 10:08:04,552 - INFO - Extracting academic disciplines and keyphrases for text: Embark on a transformative journey into Generative...
# 2024-08-06 10:08:09,746 - INFO - Extracting academic disciplines and keyphrases for text: Formulate and evaluate proposals grounded in first...
# 2024-08-06 10:08:09,817 - INFO - Extracting academic disciplines and keyphrases for text: The AI for Healthcare program offers two courses t...
# 2024-08-06 10:08:21,689 - INFO - Extracting academic disciplines and keyphrases for text: This Data Visualization Nanodegree program covers ...
# 2024-08-06 10:08:22,784 - INFO - Extracting academic disciplines and keyphrases for text: Udacityâ€™s Cybersecurity for Business Leaders pro...
# 2024-08-06 10:08:23,709 - INFO - Extracting academic disciplines and keyphrases for text: In this Nanodegree, you will learn to build acquis...
# 2024-08-06 10:08:25,772 - INFO - Extracting academic disciplines and keyphrases for text: This program offers a comprehensive exploration of...
# 2024-08-06 10:08:26,609 - INFO - Extracting academic disciplines and keyphrases for text: This program provides a comprehensive education in...
# 2024-08-06 10:08:31,204 - INFO - Extracting academic disciplines and keyphrases for text: The most effective products start with a comprehen...
# 2024-08-06 10:08:37,215 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of User Experience Design....
# 2024-08-06 10:08:41,079 - INFO - Extracting academic disciplines and keyphrases for text: Learn about the data analysis process, key steps i...
# 2024-08-06 10:08:42,122 - INFO - Extracting academic disciplines and keyphrases for text: In this program, students will learn to run and ma...
# 2024-08-06 10:08:44,164 - INFO - Extracting academic disciplines and keyphrases for text: Get hands-on practice with over 100 data structure...
# 2024-08-06 10:08:44,835 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore concepts of DevOp...
# 2024-08-06 10:08:45,659 - INFO - Extracting academic disciplines and keyphrases for text: The goal of this program is to prepare students fo...
# 2024-08-06 10:08:52,045 - INFO - Extracting academic disciplines and keyphrases for text: Students will learn essential skills, including de...
# 2024-08-06 10:08:54,329 - INFO - Extracting academic disciplines and keyphrases for text: Product management is one of the highest-impact, m...
# 2024-08-06 10:08:55,519 - INFO - Extracting academic disciplines and keyphrases for text: Learn programming skills needed to uncover pattern...
# 2024-08-06 10:08:55,567 - INFO - Extracting academic disciplines and keyphrases for text: Discover Artificial Intelligence and Machine Learn...
# 2024-08-06 10:08:56,728 - INFO - Extracting academic disciplines and keyphrases for text: Learn the latest skills to process data in real-ti...
# 2024-08-06 10:08:58,887 - INFO - Extracting academic disciplines and keyphrases for text: In this world where everything is digital, your mi...
# 2024-08-06 10:08:59,954 - INFO - Extracting academic disciplines and keyphrases for text: In this Nanodegree, you will learn foundational sk...
# 2024-08-06 10:09:03,368 - INFO - Extracting academic disciplines and keyphrases for text: Data analysis and visualization is one of the high...
# 2024-08-06 10:09:03,389 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will use learn the basics of J...
# 2024-08-06 10:09:04,118 - INFO - Extracting academic disciplines and keyphrases for text: This course is all about how to foster a culture t...
# 2024-08-06 10:09:08,865 - INFO - Extracting academic disciplines and keyphrases for text: Learn best practices for using an Agile framework ...
# 2024-08-06 10:09:08,880 - INFO - Extracting academic disciplines and keyphrases for text: Learn the essentials of building a self-driving ca...
# 2024-08-06 10:09:09,660 - INFO - Extracting academic disciplines and keyphrases for text: The Intro to Machine Learning with Pytorch program...
# 2024-08-06 10:09:10,380 - INFO - Extracting academic disciplines and keyphrases for text: This Nanodegree explores digital art and graphic d...
# 2024-08-06 10:09:10,491 - INFO - Extracting academic disciplines and keyphrases for text: In this program, students will master data fundame...
# 2024-08-06 10:09:10,506 - INFO - Extracting academic disciplines and keyphrases for text: Security is embedded in all we do online and is a ...
# 2024-08-06 10:09:14,613 - INFO - Extracting academic disciplines and keyphrases for text: This course covers foundational deep learning theo...
# 2024-08-06 10:09:14,632 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn the basics of deplo...
# 2024-08-06 10:09:18,681 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn the core components...
# 2024-08-06 10:09:21,227 - INFO - Extracting academic disciplines and keyphrases for text: This course will give you a high-level overview of...
# 2024-08-06 10:09:22,422 - INFO - Extracting academic disciplines and keyphrases for text: In this program, you will embark on an immersive j...
# 2024-08-06 10:09:23,194 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we'll be exploring how to create w...
# 2024-08-06 10:09:24,024 - INFO - Extracting academic disciplines and keyphrases for text: Data science is one of the highest-impact, most in...
# 2024-08-06 10:09:24,055 - INFO - Extracting academic disciplines and keyphrases for text: Get your start in the high-growth field of cyberse...
# 2024-08-06 10:09:30,279 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will be introduced to The Agil...
# 2024-08-06 10:09:31,327 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we will learn the key concepts of ...
# 2024-08-06 10:09:32,315 - INFO - Extracting academic disciplines and keyphrases for text: This course will give you the basic information yo...
# 2024-08-06 10:09:34,868 - INFO - Extracting academic disciplines and keyphrases for text: In this course, students will learn how to approac...
# 2024-08-06 10:09:34,898 - INFO - Extracting academic disciplines and keyphrases for text: Digital Project Management is one of the most in-d...
# 2024-08-06 10:09:35,012 - INFO - Extracting academic disciplines and keyphrases for text: This course is designed for developers who want to...
# 2024-08-06 10:09:35,178 - INFO - Extracting academic disciplines and keyphrases for text: Agile is one of the highest-impact, most in-demand...
# 2024-08-06 10:09:35,845 - INFO - Extracting academic disciplines and keyphrases for text: This program teaches students how to deploy, test,...
# 2024-08-06 10:09:38,853 - INFO - Extracting academic disciplines and keyphrases for text: Dive into generative AI with this course, which ex...
# 2024-08-06 10:09:40,236 - INFO - Extracting academic disciplines and keyphrases for text: The Generative AI for Business Leaders course is d...
# 2024-08-06 10:09:41,155 - INFO - Extracting academic disciplines and keyphrases for text: Take advantage of the high demand for people with ...
# 2024-08-06 10:09:43,121 - INFO - Extracting academic disciplines and keyphrases for text: Self-healing architecture is resilient enough to w...
# 2024-08-06 10:09:44,280 - INFO - Extracting academic disciplines and keyphrases for text: In this program, you will delve into essential con...
# 2024-08-06 10:09:47,744 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we will look at how SREs view avai...
# 2024-08-06 10:09:54,181 - INFO - Extracting academic disciplines and keyphrases for text: In this course you will start using SwiftUI and Xc...
# 2024-08-06 10:09:55,879 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces students to utilizing Azure...
# 2024-08-06 10:09:55,992 - INFO - Extracting academic disciplines and keyphrases for text: In this program, you will embark on an immersive j...
# 2024-08-06 10:09:56,437 - INFO - Extracting academic disciplines and keyphrases for text: Autonomous system is one of the highest-impact, mo...
# 2024-08-06 10:09:56,441 - INFO - Extracting academic disciplines and keyphrases for text: Create a re-usable end-to-end pipeline for predict...
# 2024-08-06 10:10:06,929 - INFO - Extracting academic disciplines and keyphrases for text: The Discovering World Models course focuses on hel...
# 2024-08-06 10:10:07,741 - INFO - Extracting academic disciplines and keyphrases for text: This course provides a comprehensive high-level ov...
# 2024-08-06 10:10:14,452 - INFO - Extracting academic disciplines and keyphrases for text: Unlock the power of artificial intelligence on GCP...
# 2024-08-06 10:10:21,581 - INFO - Extracting academic disciplines and keyphrases for text: In this lesson, you will learn about CLIP, which i...
# 2024-08-06 10:10:22,313 - INFO - Extracting academic disciplines and keyphrases for text: In the project, you'll develop, monitor, and deplo...
# 2024-08-06 10:10:24,840 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we will learn about the founding c...
# 2024-08-06 10:10:25,180 - INFO - Extracting academic disciplines and keyphrases for text: The purpose of this course is to take a deep dive ...
# 2024-08-06 10:10:26,427 - INFO - Extracting academic disciplines and keyphrases for text: Learn how computers process and understand image d...
# 2024-08-06 10:10:26,438 - INFO - Extracting academic disciplines and keyphrases for text: Dive deeper into how computers understand and crea...
# 2024-08-06 10:10:28,270 - INFO - Extracting academic disciplines and keyphrases for text: Data Privacy, the protection of personal informati...
# 2024-08-06 10:10:28,598 - INFO - Extracting academic disciplines and keyphrases for text: Learn the data science process, including how to b...
# 2024-08-06 10:10:29,120 - INFO - Extracting academic disciplines and keyphrases for text: This introductory Solidity course covers essential...
# 2024-08-06 10:10:29,137 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces the fundamental concepts be...
# 2024-08-06 10:10:31,953 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn fundamental topics ...
# 2024-08-06 10:10:32,654 - INFO - Extracting academic disciplines and keyphrases for text: Copilot is a new service provided by GitHub that p...
# 2024-08-06 10:10:35,570 - INFO - Extracting academic disciplines and keyphrases for text: In this course, dive into game audio, user interfa...
# 2024-08-06 10:10:38,672 - INFO - Extracting academic disciplines and keyphrases for text: Welcome to Application Programming Interfaces, or ...
# 2024-08-06 10:10:47,546 - INFO - Extracting academic disciplines and keyphrases for text: This lesson provides an introduction to the cloud ...
# 2024-08-06 10:10:51,981 - INFO - Extracting academic disciplines and keyphrases for text: Explore web design basics with Figma, focusing on ...
# 2024-08-06 10:10:52,600 - INFO - Extracting academic disciplines and keyphrases for text: The purpose of this course is to introduce student...
# 2024-08-06 10:10:53,878 - INFO - Extracting academic disciplines and keyphrases for text: In this course, explore 2D Sprite animation, game ...
# 2024-08-06 10:10:54,351 - INFO - Extracting academic disciplines and keyphrases for text: This course covers the foundational aspects of pla...
# 2024-08-06 10:10:57,771 - INFO - Extracting academic disciplines and keyphrases for text: Learn about the next generation of data management...
# 2024-08-06 10:11:00,630 - INFO - Extracting academic disciplines and keyphrases for text: Learn to understand and implement a Deep Convoluti...
# 2024-08-06 10:11:00,677 - INFO - Extracting academic disciplines and keyphrases for text: The Generative AI Solutions course offers a deep d...
# 2024-08-06 10:11:02,510 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn fundamental topics ...
# 2024-08-06 10:11:03,006 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces the complexity of AI govern...
# 2024-08-06 10:11:08,125 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn to use AWS to creat...
# 2024-08-06 10:11:08,132 - INFO - Extracting academic disciplines and keyphrases for text: This course covers I2C communications, debugging I...
# 2024-08-06 10:11:09,810 - INFO - Extracting academic disciplines and keyphrases for text: Connectivity is an essential part of our world. In...
# 2024-08-06 10:11:13,501 - INFO - Extracting academic disciplines and keyphrases for text: Unleash your creativity with our introductory cour...
# 2024-08-06 10:11:13,815 - INFO - Extracting academic disciplines and keyphrases for text: Introduction to circuits!...
# 2024-08-06 10:11:13,815 - INFO - Extracting academic disciplines and keyphrases for text: This course will cover processing that is triggere...
# 2024-08-06 10:11:16,216 - INFO - Extracting academic disciplines and keyphrases for text: These lessons cover Masking in raster design, expl...
# 2024-08-06 10:11:16,579 - INFO - Extracting academic disciplines and keyphrases for text: "Introducing Generative AI with AWS," a beginner-l...
# 2024-08-06 10:11:16,626 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll master Unity for game devel...
# 2024-08-06 10:11:17,742 - INFO - Extracting academic disciplines and keyphrases for text: Learn what business intelligence analytics is and ...
# 2024-08-06 10:11:19,225 - INFO - Extracting academic disciplines and keyphrases for text: This course provides an introduction to Swift, App...
# 2024-08-06 10:11:19,313 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore the essentials of...
# 2024-08-06 10:11:27,757 - INFO - Extracting academic disciplines and keyphrases for text: Unleash your creativity in video editing!
#  From t...
# 2024-08-06 10:11:29,663 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll master data management and ...
# 2024-08-06 10:11:36,875 - INFO - Extracting academic disciplines and keyphrases for text: Topics explore a wide set of areas of 5G wireless ...
# 2024-08-06 10:11:37,396 - INFO - Extracting academic disciplines and keyphrases for text: Welcome to the digital arts! This lesson delves in...
# 2024-08-06 10:11:37,766 - INFO - Extracting academic disciplines and keyphrases for text: This course covers sensor integration and communic...
# 2024-08-06 10:11:40,195 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn about the big data ...
# 2024-08-06 10:11:41,860 - INFO - Extracting academic disciplines and keyphrases for text: This course covers the essentials of digital outpu...
# 2024-08-06 10:11:50,051 - INFO - Extracting academic disciplines and keyphrases for text: This course covers multiple RNN architectures and ...
# 2024-08-06 10:11:51,380 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll learn to create cloud-bas...
# 2024-08-06 10:11:54,078 - INFO - Extracting academic disciplines and keyphrases for text: This course covers the essentials of stepper motor...
# 2024-08-06 10:11:54,217 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll build pipelines leveraging ...
# 2024-08-06 10:11:59,252 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces Convolutional Neural Networ...
# 2024-08-06 10:12:02,311 - INFO - Extracting academic disciplines and keyphrases for text: With the advent of cloud computing, along came sev...
# 2024-08-06 10:12:03,522 - INFO - Extracting academic disciplines and keyphrases for text: The course is for product managers who are buildin...
# 2024-08-06 10:12:05,527 - INFO - Extracting academic disciplines and keyphrases for text: Explore the art of character animation, understand...
# 2024-08-06 10:12:07,114 - INFO - Extracting academic disciplines and keyphrases for text: This course covers how to connect and program embe...
# 2024-08-06 10:12:09,795 - INFO - Extracting academic disciplines and keyphrases for text: In this short course, we'll look at embedded syste...
# 2024-08-06 10:12:16,095 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces Product Development, with a...
# 2024-08-06 10:12:17,599 - INFO - Extracting academic disciplines and keyphrases for text: This course covers how digital signals are process...
# 2024-08-06 10:12:19,102 - INFO - Extracting academic disciplines and keyphrases for text: Ethical AI is one of the highest-impact, most in-d...
# 2024-08-06 10:12:19,149 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore the fascinating f...
# 2024-08-06 10:12:22,845 - INFO - Extracting academic disciplines and keyphrases for text: This course focuses on movement and rhythm in comp...
# 2024-08-06 10:12:23,516 - INFO - Extracting academic disciplines and keyphrases for text: This course will provide an overview of embedded s...
# 2024-08-06 10:12:35,797 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will delve into the captivatin...
# 2024-08-06 10:12:35,807 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will delve into the world of p...
# 2024-08-06 10:12:39,368 - INFO - Extracting academic disciplines and keyphrases for text: In this introductory course on digital arts, you'l...
# 2024-08-06 10:12:42,282 - INFO - Extracting academic disciplines and keyphrases for text: This lesson will provide you with a comprehensive ...
# 2024-08-06 10:12:43,938 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you learn the basics of blockchain...
# 2024-08-06 10:12:46,378 - INFO - Extracting academic disciplines and keyphrases for text: This learning experience will guide you through us...
# 2024-08-06 10:12:46,383 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will engage with Embedded Syst...
# 2024-08-06 10:12:48,943 - INFO - Extracting academic disciplines and keyphrases for text: The preparation phase is the most important step i...
# 2024-08-06 10:12:49,300 - INFO - Extracting academic disciplines and keyphrases for text: This course is designed to introduce you to the wo...
# 2024-08-06 10:12:50,902 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn how to stretch for ...
# 2024-08-06 10:12:51,268 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn how to integrate data...
# 2024-08-06 10:12:51,356 - INFO - Extracting academic disciplines and keyphrases for text: Blockchain is one of the most in-demand skills. In...
# 2024-08-06 10:12:51,380 - INFO - Extracting academic disciplines and keyphrases for text: Design Thinking is one of the most in-demand skill...
# 2024-08-06 10:12:58,941 - INFO - Extracting academic disciplines and keyphrases for text: Serverless technologies have become very popular r...
# 2024-08-06 10:12:59,046 - INFO - Extracting academic disciplines and keyphrases for text: UX Design is one of the most in-demand skills. In ...
# 2024-08-06 10:12:59,099 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore the fundamentals ...
# 2024-08-06 10:13:01,114 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll learn to build, orchestra...
# 2024-08-06 10:13:01,805 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore Embedded Systems,...
# 2024-08-06 10:13:09,060 - INFO - Extracting academic disciplines and keyphrases for text: This course establishes a framework for data analy...
# 2024-08-06 10:13:09,080 - INFO - Extracting academic disciplines and keyphrases for text: This course is about effectively engaging audience...
# 2024-08-06 10:13:10,594 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will delve into Embedded Syste...
# 2024-08-06 10:13:13,361 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn the basics of secur...
# 2024-08-06 10:13:14,195 - INFO - Extracting academic disciplines and keyphrases for text: The cloud has become a key enabler for innovation ...
# 2024-08-06 10:13:14,308 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll learn the fundamentals of...
# 2024-08-06 10:13:20,412 - INFO - Extracting academic disciplines and keyphrases for text: This course will give you an introduction to data ...
# 2024-08-06 10:13:23,030 - INFO - Extracting academic disciplines and keyphrases for text: Students will learn the fundamentals skills, inclu...
# 2024-08-06 10:13:23,438 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we will create a custom Q&A bot po...
# 2024-08-06 10:13:23,728 - INFO - Extracting academic disciplines and keyphrases for text: This course delves into texture in both fine arts ...
# 2024-08-06 10:13:25,516 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore the fundamentals ...
# 2024-08-06 10:13:25,766 - INFO - Extracting academic disciplines and keyphrases for text: Learn about the big data ecosystem and how to use ...
# 2024-08-06 10:13:28,418 - INFO - Extracting academic disciplines and keyphrases for text: Data literacy is one of the highest-impact, most i...
# 2024-08-06 10:13:28,433 - INFO - Extracting academic disciplines and keyphrases for text: This course is a crucial step in Power BI for anyo...
# 2024-08-06 10:13:29,410 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn to create cloud-bas...
# 2024-08-06 10:13:29,410 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn fundamental topics ...
# 2024-08-06 10:13:29,430 - INFO - Extracting academic disciplines and keyphrases for text: Business analytics is one of the highest-impact, m...
# 2024-08-06 10:13:29,437 - INFO - Extracting academic disciplines and keyphrases for text: Email is an effective marketing channel, especiall...
# 2024-08-06 10:13:32,850 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn fundamental React con...
# 2024-08-06 10:13:38,277 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces students to a selection of ...
# 2024-08-06 10:13:40,135 - INFO - Extracting academic disciplines and keyphrases for text: Data wrangling is a set of processes for turning r...
# 2024-08-06 10:13:40,498 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will be introduced to the indu...
# 2024-08-06 10:13:42,243 - INFO - Extracting academic disciplines and keyphrases for text: Programming is one of the highest-impact, most in-...
# 2024-08-06 10:13:42,259 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces learners to multi-cloud arc...
# 2024-08-06 10:13:45,918 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn about implementing ...
# 2024-08-06 10:13:48,219 - INFO - Extracting academic disciplines and keyphrases for text: Build your foundational knowledge in Google Cloud ...
# 2024-08-06 10:13:48,347 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn how to build end-to-e...
# 2024-08-06 10:13:53,724 - INFO - Extracting academic disciplines and keyphrases for text: Explore the possibilities of React Native for buil...
# 2024-08-06 10:13:54,424 - INFO - Extracting academic disciplines and keyphrases for text: Learn the data analysis process of questioning, wr...
# 2024-08-06 10:13:56,739 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces the fundamental concepts an...
# 2024-08-06 10:13:59,144 - INFO - Extracting academic disciplines and keyphrases for text: This learning journey is designed to provide a com...
# 2024-08-06 10:13:59,318 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces the fundamental security pl...
# 2024-08-06 10:14:00,718 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will gain practical skills in ...
# 2024-08-06 10:14:04,569 - INFO - Extracting academic disciplines and keyphrases for text: In this course you will learn how to train, finetu...
# 2024-08-06 10:14:07,106 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll design and build bot soluti...
# 2024-08-06 10:14:07,745 - INFO - Extracting academic disciplines and keyphrases for text: This lesson covers vector databases, crucial for e...
# 2024-08-06 10:14:08,138 - INFO - Extracting academic disciplines and keyphrases for text: This course empowers the students to be more effic...
# 2024-08-06 10:14:09,104 - INFO - Extracting academic disciplines and keyphrases for text: Learn voice user interface techniques that turn sp...
# 2024-08-06 10:14:10,910 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces the zero trust security mod...
# 2024-08-06 10:14:12,150 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn about how to craft ...
# 2024-08-06 10:14:12,909 - INFO - Extracting academic disciplines and keyphrases for text: Digital art and graphic design shape our visual en...
# 2024-08-06 10:14:16,026 - INFO - Extracting academic disciplines and keyphrases for text: Learn about Apache Airflow DAGs and how to use the...
# 2024-08-06 10:14:16,042 - INFO - Extracting academic disciplines and keyphrases for text: Apply deep learning architectures to reinforcement...
# 2024-08-06 10:14:16,784 - INFO - Extracting academic disciplines and keyphrases for text: Expand your understanding of JavaScript syntax and...
# 2024-08-06 10:14:19,707 - INFO - Extracting academic disciplines and keyphrases for text: This course discusses how to use AWS services to t...
# 2024-08-06 10:14:20,525 - INFO - Extracting academic disciplines and keyphrases for text: Application security is a critical part of any ent...
# 2024-08-06 10:14:26,562 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will go over the best practice...
# 2024-08-06 10:14:30,647 - INFO - Extracting academic disciplines and keyphrases for text: This course will teach you the basics behind embed...
# 2024-08-06 10:14:31,681 - INFO - Extracting academic disciplines and keyphrases for text: Optimizing visibility in search engine results is ...
# 2024-08-06 10:14:32,076 - INFO - Extracting academic disciplines and keyphrases for text: With the transition to electronic health records (...
# 2024-08-06 10:14:34,783 - INFO - Extracting academic disciplines and keyphrases for text: Learn to use Bayes Nets to represent complex proba...
# 2024-08-06 10:14:35,534 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll start learning what machine...
# 2024-08-06 10:14:36,138 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to select the most appropriate data visu...
# 2024-08-06 10:14:36,138 - INFO - Extracting academic disciplines and keyphrases for text: Learn about the core data structures used in progr...
# 2024-08-06 10:14:36,154 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn about the foundations...
# 2024-08-06 10:14:37,671 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn how to: design a secu...
# 2024-08-06 10:14:38,714 - INFO - Extracting academic disciplines and keyphrases for text: Learn advanced techniques like word embeddings, de...
# 2024-08-06 10:14:40,928 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will discover the importance o...
# 2024-08-06 10:14:44,610 - INFO - Extracting academic disciplines and keyphrases for text: This course covers advanced topics related to depl...
# 2024-08-06 10:14:44,625 - INFO - Extracting academic disciplines and keyphrases for text: This section provides an overview of the program a...
# 2024-08-06 10:14:50,221 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to use version control to save and share...
# 2024-08-06 10:14:50,234 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn how to plan and imple...
# 2024-08-06 10:14:52,733 - INFO - Extracting academic disciplines and keyphrases for text: This course will prepare you for managing freelanc...
# 2024-08-06 10:14:53,010 - INFO - Extracting academic disciplines and keyphrases for text: This course is designed for anyone who would like ...
# 2024-08-06 10:14:57,981 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of User Experience Design....
# 2024-08-06 10:14:57,986 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces the fundamental tools neede...
# 2024-08-06 10:14:58,475 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn how to plan and build...
# 2024-08-06 10:14:58,650 - INFO - Extracting academic disciplines and keyphrases for text: This course steps you through the basics of digita...
# 2024-08-06 10:15:01,219 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces Java ecosystem topics that ...
# 2024-08-06 10:15:04,193 - INFO - Extracting academic disciplines and keyphrases for text: Learn to use REST Proxy, Kafka Connect, KSQL, and ...
# 2024-08-06 10:15:05,661 - INFO - Extracting academic disciplines and keyphrases for text: This course focuses on identity and access managem...
# 2024-08-06 10:15:08,251 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will go over the best practice...
# 2024-08-06 10:15:11,256 - INFO - Extracting academic disciplines and keyphrases for text: We start by exploring the concept of data governan...
# 2024-08-06 10:15:19,036 - INFO - Extracting academic disciplines and keyphrases for text: The focus of the course is on managing state in an...
# 2024-08-06 10:15:26,200 - INFO - Extracting academic disciplines and keyphrases for text: Start coding with Python, drawing upon libraries a...
# 2024-08-06 10:15:31,545 - INFO - Extracting academic disciplines and keyphrases for text: Building the right data infrastructure for your bu...
# 2024-08-06 10:15:32,771 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of neural networks with Pyt...
# 2024-08-06 10:15:35,191 - INFO - Extracting academic disciplines and keyphrases for text: Once a need has been defined, and a product has be...
# 2024-08-06 10:15:41,097 - INFO - Extracting academic disciplines and keyphrases for text: Search engines are an essential part of the online...
# 2024-08-06 10:15:41,125 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn how security analys...
# 2024-08-06 10:15:41,197 - INFO - Extracting academic disciplines and keyphrases for text: In this part, you will build the backend for a cof...
# 2024-08-06 10:15:45,456 - INFO - Extracting academic disciplines and keyphrases for text: In this course, students will learn about the majo...
# 2024-08-06 10:15:47,043 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll learn advanced data visua...
# 2024-08-06 10:15:49,132 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will apply the skills you lear...
# 2024-08-06 10:15:49,138 - INFO - Extracting academic disciplines and keyphrases for text: Develop an understanding of containerized environm...
# 2024-08-06 10:15:50,924 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll learn to represent and st...
# 2024-08-06 10:15:57,647 - INFO - Extracting academic disciplines and keyphrases for text: SQL is one of the most versatile tools available w...
# 2024-08-06 10:15:59,744 - INFO - Extracting academic disciplines and keyphrases for text: Get acquainted with how the web works! Learn about...
# 2024-08-06 10:16:00,984 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll start by exploring the cu...
# 2024-08-06 10:16:07,545 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will use AWS tools to identify...
# 2024-08-06 10:16:07,623 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will explore best practices an...
# 2024-08-06 10:16:07,701 - INFO - Extracting academic disciplines and keyphrases for text: Learn the data science process, including how to b...
# 2024-08-06 10:16:07,718 - INFO - Extracting academic disciplines and keyphrases for text: Using Power BI, the overarching goal of the course...
# 2024-08-06 10:16:09,967 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of User Experience Design....
# 2024-08-06 10:16:09,970 - INFO - Extracting academic disciplines and keyphrases for text: You'll learn the skills needed to traverse the sta...
# 2024-08-06 10:16:12,647 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will begin your exploration in...
# 2024-08-06 10:16:13,024 - INFO - Extracting academic disciplines and keyphrases for text: Social Media is a powerful channel for marketers. ...
# 2024-08-06 10:16:16,443 - INFO - Extracting academic disciplines and keyphrases for text: Databases need to be structured properly to enable...
# 2024-08-06 10:16:18,292 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn the end-to-end proc...
# 2024-08-06 10:16:18,638 - INFO - Extracting academic disciplines and keyphrases for text: In order to be a great Java developer you must fir...
# 2024-08-06 10:16:19,345 - INFO - Extracting academic disciplines and keyphrases for text: The best products have gone through rounds of iter...
# 2024-08-06 10:16:24,328 - INFO - Extracting academic disciplines and keyphrases for text: In this project, you will use the skills youâ€™ve ...
# 2024-08-06 10:16:26,183 - INFO - Extracting academic disciplines and keyphrases for text: Measurability is what makes Digital Marketing uniq...
# 2024-08-06 10:16:26,717 - INFO - Extracting academic disciplines and keyphrases for text: The best Java programs combine excellent software ...
# 2024-08-06 10:16:27,612 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we will explore IAM to help protec...
# 2024-08-06 10:16:33,803 - INFO - Extracting academic disciplines and keyphrases for text: In this course, youâ€™ll learn the process of desi...
# 2024-08-06 10:16:36,068 - INFO - Extracting academic disciplines and keyphrases for text: Learn to create relational and NoSQL data models t...
# 2024-08-06 10:16:38,919 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will learn how to communicate ...
# 2024-08-06 10:16:43,499 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of neural networks with Pyt...
# 2024-08-06 10:16:43,520 - INFO - Extracting academic disciplines and keyphrases for text: Learn the importance of code organization and how ...
# 2024-08-06 10:16:43,997 - INFO - Extracting academic disciplines and keyphrases for text: In this course you will grow your expertise in the...
# 2024-08-06 10:16:46,564 - INFO - Extracting academic disciplines and keyphrases for text: Continue to advance your skills as a beginning pro...
# 2024-08-06 10:16:48,697 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of time series forecasting ...
# 2024-08-06 10:16:50,427 - INFO - Extracting academic disciplines and keyphrases for text: In this course, students will learn how to carry P...
# 2024-08-06 10:16:50,626 - INFO - Extracting academic disciplines and keyphrases for text: Learn the basic concepts of data analysis and desc...
# 2024-08-06 10:16:52,394 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to prepare data to ensure the efficacy o...
# 2024-08-06 10:16:54,199 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you will be introduced to The Agil...
# 2024-08-06 10:16:54,217 - INFO - Extracting academic disciplines and keyphrases for text: The Agile approach to planning is an iterative pro...
# 2024-08-06 10:16:59,050 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to design business experiments and analy...
# 2024-08-06 10:17:01,590 - INFO - Extracting academic disciplines and keyphrases for text: Learn basic programming with Python, one of the mo...
# 2024-08-06 10:17:01,608 - INFO - Extracting academic disciplines and keyphrases for text: This course will teach you how to start from scrat...
# 2024-08-06 10:17:01,656 - INFO - Extracting academic disciplines and keyphrases for text: This course focuses on the syntax of the Swift pro...
# 2024-08-06 10:17:01,656 - INFO - Extracting academic disciplines and keyphrases for text: This course provides an overview of governance, ri...
# ...
# 2024-08-06 10:18:44,819 - INFO - Extracting academic disciplines and keyphrases for text: Learn the basics of deep learning, and build your ...
# 2024-08-06 10:18:44,819 - INFO - Extracting academic disciplines and keyphrases for text: This course offers a quick practical introduction ...
# 2024-08-06 10:18:45,070 - INFO - Extracting academic disciplines and keyphrases for text: Intro to Inferential Statistics will teach you how...
# 2024-08-06 10:18:47,408 - INFO - Extracting academic disciplines and keyphrases for text: In this course you'll implement Account Kit and Fa...
# 2024-08-06 10:18:49,668 - INFO - Extracting academic disciplines and keyphrases for text: Learn to apply deep learning architectures to comp...
# 2024-08-06 10:18:49,694 - INFO - Extracting academic disciplines and keyphrases for text: Master computer vision and image processing essent...
# 2024-08-06 10:18:49,706 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to locate an object and track it over ti...
# 2024-08-06 10:18:49,858 - INFO - Extracting academic disciplines and keyphrases for text: This course offers an entry into the world of codi...
# 2024-08-06 10:18:52,923 - INFO - Extracting academic disciplines and keyphrases for text: Learn three cutting-edge technologies for privacy-...
# 2024-08-06 10:18:52,925 - INFO - Extracting academic disciplines and keyphrases for text: If you are interested in learning more about virtu...
# 2024-08-06 10:18:52,999 - INFO - Extracting academic disciplines and keyphrases for text: Start off with a basic introduction to topics cove...
# 2024-08-06 10:18:53,085 - INFO - Extracting academic disciplines and keyphrases for text: This course covers everything you need to know to ...
# 2024-08-06 10:18:55,179 - INFO - Extracting academic disciplines and keyphrases for text: Sharpen your expertise in tackling complex data ch...
# 2024-08-06 10:18:55,355 - INFO - Extracting academic disciplines and keyphrases for text: Learn the fundamentals of back-end web development...
# 2024-08-06 10:18:55,418 - INFO - Extracting academic disciplines and keyphrases for text: Learn the basics of digital project management tha...
# 2024-08-06 10:18:55,436 - INFO - Extracting academic disciplines and keyphrases for text: Identify key parts of self-driving cars, utilize A...
# 2024-08-06 10:18:56,151 - INFO - Extracting academic disciplines and keyphrases for text: Data Scientists spend most of their time cleaning ...
# 2024-08-06 10:18:56,589 - INFO - Extracting academic disciplines and keyphrases for text: This class will teach you the end-to-end process o...
# 2024-08-06 10:18:57,230 - INFO - Extracting academic disciplines and keyphrases for text: Learn the distinguishing language features of Obje...
# 2024-08-06 10:18:57,533 - INFO - Extracting academic disciplines and keyphrases for text: Learn about AutoLayout and how to use stack views ...
# 2024-08-06 10:19:01,581 - INFO - Extracting academic disciplines and keyphrases for text: In this course you will learn all about Object Ori...
# 2024-08-06 10:19:01,595 - INFO - Extracting academic disciplines and keyphrases for text: Get ready to analyze, visualize, and interpret dat...
# 2024-08-06 10:19:01,849 - INFO - Extracting academic disciplines and keyphrases for text: Deploy your own Hadoop cluster to crunch some big ...
# 2024-08-06 10:19:02,033 - INFO - Extracting academic disciplines and keyphrases for text: Immerse yourself in the full lifecycle of AIoT-ena...
# 2024-08-06 10:19:02,152 - INFO - Extracting academic disciplines and keyphrases for text: Cryptography is present in everyday life, from pay...
# 2024-08-06 10:19:02,204 - INFO - Extracting academic disciplines and keyphrases for text: In this course, you'll learn how to plan and build...
# 2024-08-06 10:19:02,211 - INFO - Extracting academic disciplines and keyphrases for text: The goal of the Site Reliability Engineer (SRE) Na...
# 2024-08-06 10:19:02,220 - INFO - Extracting academic disciplines and keyphrases for text: Write Python code to find numerical solutions to s...
# 2024-08-06 10:19:04,571 - INFO - Extracting academic disciplines and keyphrases for text: Explore the foundational concepts of designing and...
# 2024-08-06 10:19:07,453 - INFO - Extracting academic disciplines and keyphrases for text: This course is an entry point into the world of AI...
# 2024-08-06 10:19:08,888 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to calculate eigenvalues and eigenvector...
# 2024-08-06 10:19:09,112 - INFO - Extracting academic disciplines and keyphrases for text: We live in a time of unprecedented access to infor...
# 2024-08-06 10:19:09,131 - INFO - Extracting academic disciplines and keyphrases for text: Go on a journey through psychological concepts and...
# 2024-08-06 10:19:11,871 - INFO - Extracting academic disciplines and keyphrases for text: There's much excitement about cloud technology and...
# 2024-08-06 10:19:12,564 - INFO - Extracting academic disciplines and keyphrases for text: Learn what machine learning is and the steps invol...
# 2024-08-06 10:19:12,632 - INFO - Extracting academic disciplines and keyphrases for text: Artificial intelligence (AI) and machine learning ...
# 2024-08-06 10:19:12,909 - INFO - Extracting academic disciplines and keyphrases for text: AWS...
# 2024-08-06 10:19:12,914 - INFO - Extracting academic disciplines and keyphrases for text: Gain a high-level introduction to the field of mac...
# 2024-08-06 10:19:14,010 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to search in multi-agent environments (i...
# 2024-08-06 10:19:16,739 - INFO - Extracting academic disciplines and keyphrases for text: Explore a variety of datasets, posing and answerin...
# 2024-08-06 10:19:16,745 - INFO - Extracting academic disciplines and keyphrases for text: This course will teach you the basics behind embed...
# 2024-08-06 10:19:16,754 - INFO - Extracting academic disciplines and keyphrases for text: Discovering Predictive Analytics is designed to in...
# 2024-08-06 10:19:17,394 - INFO - Extracting academic disciplines and keyphrases for text: Introduction to Power Platform...
# 2024-08-06 10:19:17,399 - INFO - Extracting academic disciplines and keyphrases for text: The goal of this course is to teach you everything...
# 2024-08-06 10:19:17,871 - INFO - Extracting academic disciplines and keyphrases for text: Go to the places where big physics discoveries wer...
# 2024-08-06 10:19:20,481 - INFO - Extracting academic disciplines and keyphrases for text: In this short lesson, you will hear digital market...
# 2024-08-06 10:19:25,056 - INFO - Extracting academic disciplines and keyphrases for text: This class will give you an introduction to the de...
# 2024-08-06 10:19:25,062 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to model problems, and how to optimize p...
# 2024-08-06 10:19:25,068 - INFO - Extracting academic disciplines and keyphrases for text: Gemini for Google Workspace is an add-on that prov...
# 2024-08-06 10:19:25,783 - INFO - Extracting academic disciplines and keyphrases for text: Learn the basic concepts in theoretical computer s...
# 2024-08-06 10:19:25,812 - INFO - Extracting academic disciplines and keyphrases for text: This course will teach you the principles of 3D co...
# 2024-08-06 10:19:26,080 - INFO - Extracting academic disciplines and keyphrases for text: Evolve your existing career trajectory, or find yo...
# 2024-08-06 10:19:31,795 - INFO - Extracting academic disciplines and keyphrases for text: Cloud technology can bring great value to an organ...
# 2024-08-06 10:19:34,477 - INFO - Extracting academic disciplines and keyphrases for text: Gemini for Google Workspace is an add-on that prov...
# 2024-08-06 10:19:35,110 - INFO - Extracting academic disciplines and keyphrases for text: Gemini for Google Workspace is an add-on that prov...
# 2024-08-06 10:19:35,810 - INFO - Extracting academic disciplines and keyphrases for text: This course will introduce you to the basics of AI...
# 2024-08-06 10:19:35,996 - INFO - Extracting academic disciplines and keyphrases for text: Discover the art of creating a resume that stands ...
# 2024-08-06 10:19:39,880 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces diffusion models, a family ...
# 2024-08-06 10:19:41,210 - INFO - Extracting academic disciplines and keyphrases for text: In today's job market, a well-crafted cover letter...
# 2024-08-06 10:19:41,474 - INFO - Extracting academic disciplines and keyphrases for text: This lesson focuses on operationalizing enterprise...
# 2024-08-06 10:19:41,991 - INFO - Extracting academic disciplines and keyphrases for text: Learn how to structure, package, and release an ap...
# 2024-08-06 10:19:41,996 - INFO - Extracting academic disciplines and keyphrases for text: Get hands-on practice with over 100 data structure...
# 2024-08-06 10:19:42,007 - INFO - Extracting academic disciplines and keyphrases for text: In this course we will introduce you to Google She...
# 2024-08-06 10:19:44,012 - INFO - Extracting academic disciplines and keyphrases for text: This course is going to walk you through some of t...
# 2024-08-06 10:19:46,762 - INFO - Extracting academic disciplines and keyphrases for text: This course provides a comprehensive overview of t...
# 2024-08-06 10:19:47,181 - INFO - Extracting academic disciplines and keyphrases for text: This course will teach you when and why to choose ...
# 2024-08-06 10:19:47,203 - INFO - Extracting academic disciplines and keyphrases for text: This course will teach you when and why to choose ...
# 2024-08-06 10:19:47,213 - INFO - Extracting academic disciplines and keyphrases for text: Ace your Product Manager interviews and prove your...
# 2024-08-06 10:19:49,315 - INFO - Extracting academic disciplines and keyphrases for text: Start developing with Large Language Models using ...
# 2024-08-06 10:19:49,330 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces Generative AI Studio, a pro...
# 2024-08-06 10:19:49,528 - INFO - Extracting academic disciplines and keyphrases for text: This course helps you develop a strong foundation ...
# 2024-08-06 10:19:52,554 - INFO - Extracting academic disciplines and keyphrases for text: Gemini for Google Workspace is an add-on that prov...
# 2024-08-06 10:19:52,570 - INFO - Extracting academic disciplines and keyphrases for text: Gemini for Google Workspace is an add-on that prov...
# 2024-08-06 10:19:54,079 - INFO - Extracting academic disciplines and keyphrases for text: The first lesson introduces you to microlearning a...
# 2024-08-06 10:19:54,168 - INFO - Extracting academic disciplines and keyphrases for text: Boost your confidence and excel in your next techn...
# 2024-08-06 10:19:54,623 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we introduce you to Google Chat, G...
# 2024-08-06 10:19:55,694 - INFO - Extracting academic disciplines and keyphrases for text: This course will help you gain strong knowledge th...
# 2024-08-06 10:19:55,694 - INFO - Extracting academic disciplines and keyphrases for text: Develop key insights into key concepts and feature...
# 2024-08-06 10:19:57,916 - INFO - Extracting academic disciplines and keyphrases for text: Gemini for Google Workspace is an add-on that prov...
# 2024-08-06 10:19:57,928 - INFO - Extracting academic disciplines and keyphrases for text: As the use of enterprise Artificial Intelligence a...
# 2024-08-06 10:20:02,452 - INFO - Extracting academic disciplines and keyphrases for text: Learn more about what it takes to assemble a stron...
# 2024-08-06 10:20:03,474 - INFO - Extracting academic disciplines and keyphrases for text: With Google Docs, your documents are stored in the...
# 2024-08-06 10:20:05,345 - INFO - Extracting academic disciplines and keyphrases for text: Have you ever wondered how computers might crack s...
# 2024-08-06 10:20:06,886 - INFO - Extracting academic disciplines and keyphrases for text: Dive into the fundamentals of autonomous databases...
# 2024-08-06 10:20:12,178 - INFO - Extracting academic disciplines and keyphrases for text: Learn what it takes to build a successful startup ...
# 2024-08-06 10:20:12,624 - INFO - Extracting academic disciplines and keyphrases for text: This course introduces you to the Transformer arch...
# 2024-08-06 10:20:26,050 - INFO - Extracting academic disciplines and keyphrases for text: This is an introductory-level microlearning course...
# 2024-08-06 10:20:32,406 - INFO - Extracting academic disciplines and keyphrases for text: Google Drive is Googleâ€™s cloud-based file storag...
# 2024-08-06 10:20:33,269 - INFO - Extracting academic disciplines and keyphrases for text: Uncover the secrets of constructing an eye-catchin...
# 2024-08-06 10:20:34,834 - INFO - Extracting academic disciplines and keyphrases for text: This course gives you a synopsis of the encoder-de...
# 2024-08-06 10:20:47,773 - INFO - Extracting academic disciplines and keyphrases for text: Organizations of all sizes are embracing the power...
# 2024-08-06 10:20:55,085 - INFO - Extracting academic disciplines and keyphrases for text: This course will introduce you to the attention me...
# 2024-08-06 10:20:59,055 - INFO - Extracting academic disciplines and keyphrases for text: With Google Calendar, you can quickly schedule mee...
# 2024-08-06 10:20:59,683 - INFO - Extracting academic disciplines and keyphrases for text: This is an introductory level microlearning course...
# 2024-08-06 10:21:04,096 - INFO - Extracting academic disciplines and keyphrases for text: This is an introductory level microlearning course...
# 2024-08-06 10:21:06,790 - INFO - Extracting academic disciplines and keyphrases for text: Optimize your generative AI prompts using zero-sho...
# 2024-08-06 10:21:06,790 - INFO - Extracting academic disciplines and keyphrases for text: This course builds on some of the concepts covered...
# 2024-08-06 10:21:09,439 - INFO - Extracting academic disciplines and keyphrases for text: As organizations move their data and applications ...
# 2024-08-06 10:21:09,482 - INFO - Extracting academic disciplines and keyphrases for text: Many traditional enterprises use legacy systems an...
# 2024-08-06 10:21:22,218 - INFO - Extracting academic disciplines and keyphrases for text: This course teaches you how to create an image cap...
# 2024-08-06 10:21:46,303 - INFO - Extracting academic disciplines and keyphrases for text: Gmail is Googleâ€™s cloud-based email service that...
# 2024-08-06 10:21:52,358 - INFO - Extracting academic disciplines and keyphrases for text: In this course, we introduce you to Google Meet, G...
# 2024-08-06 10:22:23,531 - INFO - Extracting academic disciplines and keyphrases for text: With Google Slides, you can create and present pro...
# 2024-08-06 10:22:48,510 - INFO - Saving the updated DataFrame to C:/Users/DELL/Downloads/dataset.csv
# 2024-08-06 10:22:48,853 - INFO - Displaying the first few rows of the updated DataFrame
#                                 Course Name  \
# 0                Digital Project Management
# 1                       Enterprise Security
# 2                             Sensor Fusion
# 3        Cybersecurity for Business Leaders
# 4  Programming for Data Science with Python
#
#                                          Description  \
# 0  Digital Project Management enables the creatio...
# 1  The Enterprise Security Nanodegree program imp...
# 2  The Sensor Fusion Engineer Nanodegree program ...
# 3  Udacityâ€™s Cybersecurity for Business Leaders...
# 4  Learn programming skills needed to uncover pat...
#
#                                   Extracted Entities
# 0  services, high, development, digital project m...
# 1  design robust defenses, covering network, corp...
# 2  clustering, sensor fusion engineer nanodegree ...
# 3  computer security, stage, equip future c, role...
# 4  uncover patterns, relational databases, git, l...
